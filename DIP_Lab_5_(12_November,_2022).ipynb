# %% [markdown]
# <a href="https://colab.research.google.com/github/QuaziSamiha/Digital_Image_Processing/blob/main/DIP_Lab_5_(12_November%2C_2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
imgLina= cv2.imread('/content/drive/MyDrive/Colab Notebooks/images/lina.JPEG')
img = cv2.resize(imgLina, (200,200))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F840D8BCF50>

# %%
img=img[:,:,0]
for i in range(200):
  img[i][0]=0
  img[i][201]=0
  img[201][i]=0
  img[0][i]=0
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-4ff3eb2f109b> in <module>
#       2 for i in range(202):
#       3   img[i][0]=0
# ----> 4   img[i][201]=0
#       5   img[201][i]=0
#       6   img[0][i]=0
#
# IndexError: index 201 is out of bounds for axis 0 with size 200
